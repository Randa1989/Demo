# %% [markdown]
# <a href="https://colab.research.google.com/github/Randa1989/Demo/blob/main/Loan_Approval_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#upload csv file 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab import files
import io
import pandas as pd
data=files.upload()
# Out:
#      <input type="file" id="files-5f275ecc-68dc-4aee-816e-04b0f2e82835" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5f275ecc-68dc-4aee-816e-04b0f2e82835">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv(io.StringIO(data['Loan payments data.csv'].decode('utf-8')))

# %%
df.head
# Out:
# <bound method NDFrame.head of          Loan_ID         loan_status  Principal  terms effective_date  \
# 0    xqd20166231             PAIDOFF       1000     30       9/8/2016
# 1    xqd20168902             PAIDOFF       1000     30       9/8/2016
# 2    xqd20160003             PAIDOFF       1000     30       9/8/2016
# 3    xqd20160004             PAIDOFF       1000     15       9/8/2016
# 4    xqd20160005             PAIDOFF       1000     30       9/9/2016
# ..           ...                 ...        ...    ...            ...
# 495  xqd20160496  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 496  xqd20160497  COLLECTION_PAIDOFF       1000     15      9/12/2016
# 497  xqd20160498  COLLECTION_PAIDOFF        800     15      9/12/2016
# 498  xqd20160499  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 499  xqd20160500  COLLECTION_PAIDOFF       1000     30      9/12/2016
#
#        due_date     paid_off_time  past_due_days  age             education  \
# ...

# %%
df.head(5)
# Out:
#        Loan_ID loan_status  Principal  terms effective_date   due_date  \
# 0  xqd20166231     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 1  xqd20168902     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 2  xqd20160003     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 3  xqd20160004     PAIDOFF       1000     15       9/8/2016  9/22/2016
# 4  xqd20160005     PAIDOFF       1000     30       9/9/2016  10/8/2016
#
#      paid_off_time  past_due_days  age             education  Gender
# 0  9/14/2016 19:31            NaN   45  High School or Below    male
# 1   10/7/2016 9:00            NaN   50              Bechalor  female
# 2  9/25/2016 16:58            NaN   33              Bechalor  female
# 3  9/22/2016 20:00            NaN   27               college    male
# 4  9/23/2016 21:36            NaN   28               college  female

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Loan_ID         500 non-null    object
#  1   loan_status     500 non-null    object
#  2   Principal       500 non-null    int64
#  3   terms           500 non-null    int64
#  4   effective_date  500 non-null    object
#  5   due_date        500 non-null    object
#  6   paid_off_time   400 non-null    object
#  7   past_due_days   200 non-null    float64
#  8   age             500 non-null    int64
#  9   education       500 non-null    object
#  10  Gender          500 non-null    object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 43.1+ KB

# %%
Ndf=df.drop("Loan_ID",axis='columns')
Ndf.head(5)
# Out:
#   loan_status  Principal  terms effective_date   due_date    paid_off_time  \
# 0     PAIDOFF       1000     30       9/8/2016  10/7/2016  9/14/2016 19:31
# 1     PAIDOFF       1000     30       9/8/2016  10/7/2016   10/7/2016 9:00
# 2     PAIDOFF       1000     30       9/8/2016  10/7/2016  9/25/2016 16:58
# 3     PAIDOFF       1000     15       9/8/2016  9/22/2016  9/22/2016 20:00
# 4     PAIDOFF       1000     30       9/9/2016  10/8/2016  9/23/2016 21:36
#
#    past_due_days  age             education  Gender
# 0            NaN   45  High School or Below    male
# 1            NaN   50              Bechalor  female
# 2            NaN   33              Bechalor  female
# 3            NaN   27               college    male
# 4            NaN   28               college  female

# %%
Ndf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   loan_status     500 non-null    object
#  1   Principal       500 non-null    int64
#  2   terms           500 non-null    int64
#  3   effective_date  500 non-null    object
#  4   due_date        500 non-null    object
#  5   paid_off_time   400 non-null    object
#  6   past_due_days   200 non-null    float64
#  7   age             500 non-null    int64
#  8   education       500 non-null    object
#  9   Gender          500 non-null    object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 39.2+ KB

# %%
Ndf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   loan_status     500 non-null    object
#  1   Principal       500 non-null    int64
#  2   terms           500 non-null    int64
#  3   effective_date  500 non-null    object
#  4   due_date        500 non-null    object
#  5   paid_off_time   400 non-null    object
#  6   past_due_days   200 non-null    float64
#  7   age             500 non-null    int64
#  8   education       500 non-null    object
#  9   Gender          500 non-null    object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 39.2+ KB

# %%
print(Ndf)
# Out:
#             loan_status  Principal  terms effective_date    due_date  \
# 0               PAIDOFF       1000     30       9/8/2016   10/7/2016
# 1               PAIDOFF       1000     30       9/8/2016   10/7/2016
# 2               PAIDOFF       1000     30       9/8/2016   10/7/2016
# 3               PAIDOFF       1000     15       9/8/2016   9/22/2016
# 4               PAIDOFF       1000     30       9/9/2016   10/8/2016
# ..                  ...        ...    ...            ...         ...
# 495  COLLECTION_PAIDOFF       1000     30      9/12/2016  10/11/2016
# 496  COLLECTION_PAIDOFF       1000     15      9/12/2016   9/26/2016
# 497  COLLECTION_PAIDOFF        800     15      9/12/2016   9/26/2016
# 498  COLLECTION_PAIDOFF       1000     30      9/12/2016  11/10/2016
# 499  COLLECTION_PAIDOFF       1000     30      9/12/2016  10/11/2016
#
#         paid_off_time  past_due_days  age             education  Gender
# ...

# %%
print(Ndf.loc[67])
# Out:
# loan_status                    PAIDOFF
# Principal                         1000
# terms                               30
# effective_date               9/11/2016
# due_date                    10/10/2016
# paid_off_time          10/10/2016 9:00
# past_due_days                      NaN
# age                                 37
# education         High School or Below
# Gender                            male
# Name: 67, dtype: object

# %%
Ndf.tail(10)
# Out:
#             loan_status  Principal  terms effective_date    due_date  \
# 490  COLLECTION_PAIDOFF       1000     30      9/12/2016  10/11/2016
# 491  COLLECTION_PAIDOFF       1000     30      9/12/2016  10/11/2016
# 492  COLLECTION_PAIDOFF       1000     30      9/12/2016  10/11/2016
# 493  COLLECTION_PAIDOFF       1000     15      9/12/2016   9/26/2016
# 494  COLLECTION_PAIDOFF       1000     30      9/12/2016  10/11/2016
# 495  COLLECTION_PAIDOFF       1000     30      9/12/2016  10/11/2016
# 496  COLLECTION_PAIDOFF       1000     15      9/12/2016   9/26/2016
# 497  COLLECTION_PAIDOFF        800     15      9/12/2016   9/26/2016
# 498  COLLECTION_PAIDOFF       1000     30      9/12/2016  11/10/2016
# 499  COLLECTION_PAIDOFF       1000     30      9/12/2016  10/11/2016
#
#         paid_off_time  past_due_days  age             education  Gender
# 490  10/17/2016 10:53            6.0   38  High School or Below    male
# ...

# %%
Ndf.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Length: 500, dtype: bool

# %%
Ndf.corr()
# Out:
#                Principal     terms  past_due_days       age
# Principal       1.000000  0.534302      -0.093139 -0.092613
# terms           0.534302  1.000000      -0.102613 -0.074259
# past_due_days  -0.093139 -0.102613       1.000000 -0.053849
# age            -0.092613 -0.074259      -0.053849  1.000000

# %%
Ndf.plot()
plt.show()

# %%
Ndf.plot(kind='scatter',x='Principal',y='age')
plt.show()

# %%
Ndf.plot(kind='hist',x='Principal',y='age')
plt.show()

# %%
Ndf.plot(kind='bar',x='Principal',y='age')
plt.show()

# %%
Ndf.plot(kind='bar',x='Principal',y='age')
plt.grid()
plt.show()

# %%
Ndf.hist(figsize=(10,15),bins=10)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f67b06cc8b0>,
# ...
#       dtype=object)

# %%
Ndf.hist(column="terms", figsize=(8,8), 
 xlabelsize=20, ylabelsize=20,
 xrot=45, bins=5, color='orange')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f67b0578610>]],
#       dtype=object)

# %%
Ndf.hist(column="age", figsize=(8,8), 
 xlabelsize=20, ylabelsize=20,
 xrot=45, bins=5, color='blue')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f67afbd6220>]],
#       dtype=object)

# %%
Ages=Ndf["age"]
Ages.head()
# Out:
# 0    45
# 1    50
# 2    33
# 3    27
# 4    28
# Name: age, dtype: int64

# %%
Ndf["age"].shape
# Out:
# (500,)

# %%
Ndf["Gender"].shape
# Out:
# (500,)

# %%
minor=Ndf[Ndf["age"]<=25]
minor.head()
# Out:
#    loan_status  Principal  terms effective_date    due_date     paid_off_time  \
# 22     PAIDOFF       1000     30      9/10/2016   10/9/2016   10/9/2016 23:00
# 38     PAIDOFF       1000     15      9/11/2016   9/25/2016    9/25/2016 9:00
# 39     PAIDOFF       1000     30      9/11/2016  10/10/2016  10/10/2016 11:33
# 44     PAIDOFF       1000     15      9/11/2016   9/25/2016   9/21/2016 22:29
# 46     PAIDOFF       1000     30      9/11/2016  10/10/2016   10/8/2016 14:14
#
#     past_due_days  age             education  Gender
# 22            NaN   25  High School or Below    male
# 38            NaN   24               college    male
# 39            NaN   21              Bechalor    male
# 44            NaN   24              Bechalor  female
# 46            NaN   22  High School or Below    male

# %%
FM=Ndf[Ndf["Gender"]==('female')]
FM.head()
# Out:
#    loan_status  Principal  terms effective_date   due_date    paid_off_time  \
# 1      PAIDOFF       1000     30       9/8/2016  10/7/2016   10/7/2016 9:00
# 2      PAIDOFF       1000     30       9/8/2016  10/7/2016  9/25/2016 16:58
# 4      PAIDOFF       1000     30       9/9/2016  10/8/2016  9/23/2016 21:36
# 13     PAIDOFF        900      7      9/10/2016  9/16/2016  9/13/2016 21:57
# 21     PAIDOFF       1000     30      9/10/2016  10/9/2016  10/8/2016 17:09
#
#     past_due_days  age             education  Gender
# 1             NaN   50              Bechalor  female
# 2             NaN   33              Bechalor  female
# 4             NaN   28               college  female
# 13            NaN   26               college  female
# 21            NaN   43  High School or Below  female

# %%
display(FM)
# Out:
#             loan_status  Principal  terms effective_date    due_date  \
# 1               PAIDOFF       1000     30       9/8/2016   10/7/2016
# 2               PAIDOFF       1000     30       9/8/2016   10/7/2016
# 4               PAIDOFF       1000     30       9/9/2016   10/8/2016
# 13              PAIDOFF        900      7      9/10/2016   9/16/2016
# 21              PAIDOFF       1000     30      9/10/2016   10/9/2016
# ..                  ...        ...    ...            ...         ...
# 465  COLLECTION_PAIDOFF       1000     30      9/12/2016  10/11/2016
# 474  COLLECTION_PAIDOFF        800     15      9/12/2016   9/26/2016
# 475  COLLECTION_PAIDOFF       1000     30      9/12/2016  10/11/2016
# 476  COLLECTION_PAIDOFF        800     15      9/12/2016  10/26/2016
# 498  COLLECTION_PAIDOFF       1000     30      9/12/2016  11/10/2016
#
#         paid_off_time  past_due_days  age             education  Gender
# ...

# %%
FM.count()
# Out:
# loan_status       77
# Principal         77
# terms             77
# effective_date    77
# due_date          77
# paid_off_time     67
# past_due_days     24
# age               77
# education         77
# Gender            77
# dtype: int64

# %%
minor.count()
# Out:
# loan_status       75
# Principal         75
# terms             75
# effective_date    75
# due_date          75
# paid_off_time     57
# past_due_days     32
# age               75
# education         75
# Gender            75
# dtype: int64

# %%
Male=Ndf[Ndf["Gender"]==('male')]
Male.head()
# Out:
#   loan_status  Principal  terms effective_date   due_date    paid_off_time  \
# 0     PAIDOFF       1000     30       9/8/2016  10/7/2016  9/14/2016 19:31
# 3     PAIDOFF       1000     15       9/8/2016  9/22/2016  9/22/2016 20:00
# 5     PAIDOFF        300      7       9/9/2016  9/15/2016   9/9/2016 13:45
# 6     PAIDOFF       1000     30       9/9/2016  10/8/2016  10/7/2016 23:07
# 7     PAIDOFF       1000     30       9/9/2016  10/8/2016  10/5/2016 20:33
#
#    past_due_days  age             education Gender
# 0            NaN   45  High School or Below   male
# 3            NaN   27               college   male
# 5            NaN   35       Master or Above   male
# 6            NaN   29               college   male
# 7            NaN   36               college   male

# %%
display(Male)
# Out:
#             loan_status  Principal  terms effective_date    due_date  \
# 0               PAIDOFF       1000     30       9/8/2016   10/7/2016
# 3               PAIDOFF       1000     15       9/8/2016   9/22/2016
# 5               PAIDOFF        300      7       9/9/2016   9/15/2016
# 6               PAIDOFF       1000     30       9/9/2016   10/8/2016
# 7               PAIDOFF       1000     30       9/9/2016   10/8/2016
# ..                  ...        ...    ...            ...         ...
# 494  COLLECTION_PAIDOFF       1000     30      9/12/2016  10/11/2016
# 495  COLLECTION_PAIDOFF       1000     30      9/12/2016  10/11/2016
# 496  COLLECTION_PAIDOFF       1000     15      9/12/2016   9/26/2016
# 497  COLLECTION_PAIDOFF        800     15      9/12/2016   9/26/2016
# 499  COLLECTION_PAIDOFF       1000     30      9/12/2016  10/11/2016
#
#         paid_off_time  past_due_days  age             education Gender
# ...

# %%
Male.count()
# Out:
# loan_status       423
# Principal         423
# terms             423
# effective_date    423
# due_date          423
# paid_off_time     333
# past_due_days     176
# age               423
# education         423
# Gender            423
# dtype: int64

# %%
EDU=Ndf[Ndf["education"]==('college')]
EDU.head()
# Out:
#   loan_status  Principal  terms effective_date   due_date    paid_off_time  \
# 3     PAIDOFF       1000     15       9/8/2016  9/22/2016  9/22/2016 20:00
# 4     PAIDOFF       1000     30       9/9/2016  10/8/2016  9/23/2016 21:36
# 6     PAIDOFF       1000     30       9/9/2016  10/8/2016  10/7/2016 23:07
# 7     PAIDOFF       1000     30       9/9/2016  10/8/2016  10/5/2016 20:33
# 8     PAIDOFF       1000     30       9/9/2016  10/8/2016  10/8/2016 16:00
#
#    past_due_days  age education  Gender
# 3            NaN   27   college    male
# 4            NaN   28   college  female
# 6            NaN   29   college    male
# 7            NaN   36   college    male
# 8            NaN   28   college    male

# %%
EDU.count()
# Out:
# loan_status       220
# Principal         220
# terms             220
# effective_date    220
# due_date          220
# paid_off_time     181
# past_due_days      87
# age               220
# education         220
# Gender            220
# dtype: int64

# %%
MASTER=Ndf[Ndf["education"]==('Master or Above')]
MASTER.head()
# Out:
#     loan_status  Principal  terms effective_date   due_date   paid_off_time  \
# 5       PAIDOFF        300      7       9/9/2016  9/15/2016  9/9/2016 13:45
# 59      PAIDOFF        800     15      9/11/2016  9/25/2016  9/22/2016 6:38
# 147     PAIDOFF        300      7      9/12/2016  9/18/2016  9/18/2016 9:00
# 342  COLLECTION       1000     15      9/11/2016  9/25/2016             NaN
#
#      past_due_days  age        education Gender
# 5              NaN   35  Master or Above   male
# 59             NaN   39  Master or Above   male
# 147            NaN   37  Master or Above   male
# 342           74.0   50  Master or Above   male

# %%
old=Ndf[Ndf["age"]==50]
old.head()
# Out:
#     loan_status  Principal  terms effective_date   due_date    paid_off_time  \
# 1       PAIDOFF       1000     30       9/8/2016  10/7/2016   10/7/2016 9:00
# 49      PAIDOFF        800     15      9/11/2016  9/25/2016  9/25/2016 19:21
# 216     PAIDOFF       1000     15      9/12/2016  9/26/2016   9/21/2016 8:11
# 342  COLLECTION       1000     15      9/11/2016  9/25/2016              NaN
#
#      past_due_days  age             education  Gender
# 1              NaN   50              Bechalor  female
# 49             NaN   50  High School or Below    male
# 216            NaN   50  High School or Below    male
# 342           74.0   50       Master or Above    male

# %%
old.count()
# Out:
# loan_status       19
# Principal         19
# terms             19
# effective_date    19
# due_date          19
# paid_off_time     16
# past_due_days      9
# age               19
# education         19
# Gender            19
# dtype: int64

# %%
DELENQUE=Ndf[Ndf["loan_status"]==('PAIDOFF')]
DELENQUE.head()
# Out:
#   loan_status  Principal  terms effective_date   due_date    paid_off_time  \
# 0     PAIDOFF       1000     30       9/8/2016  10/7/2016  9/14/2016 19:31
# 1     PAIDOFF       1000     30       9/8/2016  10/7/2016   10/7/2016 9:00
# 2     PAIDOFF       1000     30       9/8/2016  10/7/2016  9/25/2016 16:58
# 3     PAIDOFF       1000     15       9/8/2016  9/22/2016  9/22/2016 20:00
# 4     PAIDOFF       1000     30       9/9/2016  10/8/2016  9/23/2016 21:36
#
#    past_due_days  age             education  Gender
# 0            NaN   45  High School or Below    male
# 1            NaN   50              Bechalor  female
# 2            NaN   33              Bechalor  female
# 3            NaN   27               college    male
# 4            NaN   28               college  female

# %%
DELENQUE.count()
# Out:
# loan_status       300
# Principal         300
# terms             300
# effective_date    300
# due_date          300
# paid_off_time     300
# past_due_days       0
# age               300
# education         300
# Gender            300
# dtype: int64

# %%
nDELENQUE=Ndf[Ndf["loan_status"]!=('PAIDOFF')]
nDELENQUE.head()
# Out:
#     loan_status  Principal  terms effective_date   due_date paid_off_time  \
# 300  COLLECTION       1000     15       9/9/2016  9/23/2016           NaN
# 301  COLLECTION       1000     30       9/9/2016  10/8/2016           NaN
# 302  COLLECTION       1000     30       9/9/2016  10/8/2016           NaN
# 303  COLLECTION        800     15       9/9/2016  9/23/2016           NaN
# 304  COLLECTION        800     15       9/9/2016  9/23/2016           NaN
#
#      past_due_days  age             education Gender
# 300           76.0   29               college   male
# 301           61.0   37  High School or Below   male
# 302           61.0   33  High School or Below   male
# 303           76.0   27               college   male
# 304           76.0   24              Bechalor   male

# %%
nDELENQUE.count()
# Out:
# loan_status       200
# Principal         200
# terms             200
# effective_date    200
# due_date          200
# paid_off_time     100
# past_due_days     200
# age               200
# education         200
# Gender            200
# dtype: int64

# %%
nDELENQUE.corr()
# Out:
#                Principal     terms  past_due_days       age
# Principal       1.000000  0.596617      -0.093139 -0.171041
# terms           0.596617  1.000000      -0.102613 -0.196304
# past_due_days  -0.093139 -0.102613       1.000000 -0.053849
# age            -0.171041 -0.196304      -0.053849  1.000000

# %%
DELENQUE.corr()
# Out:
#                Principal     terms  past_due_days       age
# Principal       1.000000  0.509251            NaN -0.057163
# terms           0.509251  1.000000            NaN  0.002718
# past_due_days        NaN       NaN            NaN       NaN
# age            -0.057163  0.002718            NaN  1.000000

# %%
nDELENQUE.hist(column="past_due_days", figsize=(8,8), 
 xlabelsize=20, ylabelsize=20,
 xrot=45, bins=5, color='blue')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f02eb92c1f0>]],
#       dtype=object)
